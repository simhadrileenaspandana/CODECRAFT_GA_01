# %%
# !pip install transformers
# !pip install torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.25.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.5.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers) (0.1.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cpu)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# Importing libraries needed for GPT-2 text generation

# transformers:
# This is a Python library developed by Hugging Face.
# It provides many pre-trained AI models like GPT-2, BERT, T5 etc.
# We use it because it allows us to easily load and use powerful AI models.


# GPT2LMHeadModel:
# GPT-2 is a language model used for text generation.
# "LM" stands for Language Model.
# "Head" refers to the final neural network layer that predicts the next word.
# So GPT2LMHeadModel = GPT-2 model + language prediction layer.
# We use this class when we want GPT-2 to generate text.


# GPT2Tokenizer:
# Computers do not understand raw text.
# A tokenizer converts text into numbers (tokens) that the model understands.
# Example:
# "AI is powerful" -> [15496, 318, 3665]
# The tokenizer also converts tokens back into readable text.


# torch:
# torch is the main library of PyTorch.
# PyTorch is a deep learning framework used to run neural networks.
# GPT-2 internally uses PyTorch to perform mathematical computations
# and to run the neural network model.

# %%
# Loading the GPT-2 model and tokenizer

# from_pretrained("gpt2") means:
# We are downloading a pretrained GPT-2 model that was already trained
# on a very large dataset from the internet.

# This saves us from training a model from scratch.

model = GPT2LMHeadModel.from_pretrained("gpt2")

# Load the tokenizer for GPT-2
# The tokenizer converts text into tokens (numbers) that the model understands.

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# Print confirmation so we know everything loaded correctly
print("GPT-2 model and tokenizer loaded successfully!")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# GPT-2 model and tokenizer loaded successfully!

# %%
# Step 5: Give a prompt to GPT-2

# A prompt is the starting text we give to the model.
# The model will continue the sentence based on what it learned during training.

prompt = "Artificial Intelligence will"

# The tokenizer converts the prompt into tokens (numbers) that the model understands.
# return_tensors="pt" means we want the tokens in PyTorch format.

inputs = tokenizer.encode(prompt, return_tensors="pt")

# Let's print the tokens to see how the text is converted into numbers
print(inputs)
# Out:
# tensor([[8001, 9542, 9345,  481]])

# %%
# Step 6: Generate text using GPT-2

# The generate() function tells GPT-2 to continue the sentence
# based on the prompt we provided earlier.

outputs = model.generate(
    inputs,                # tokens from the prompt
    max_length=50,         # maximum length of generated text
    num_return_sequences=1 # number of outputs we want
)

# Convert tokens back into readable text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Print the generated text
print(generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Artificial Intelligence will be able to do things like create a new type of robot, or create a new type of robot that can do things like create a new type of robot, or create a new type of robot that can do things like create a

# %%
# Step 7: Generate multiple outputs with sampling

outputs = model.generate(
    inputs,
    max_length=50,
    num_return_sequences=3,   # generate 3 outputs
    do_sample=True            # enables sampling instead of greedy search
)

for i, output in enumerate(outputs):
    text = tokenizer.decode(output, skip_special_tokens=True)
    print(f"Output {i+1}:")
    print(text)
    print()
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output 1:
# Artificial Intelligence will continue to be discussed as it relates to the current state of artificial intelligence. And what this means is the use of the term "machine intelligence" has been gaining currency for some time. "Machine intelligence" could be a very interesting
#
# Output 2:
# Artificial Intelligence will help with the production of smart city services that take into account all the city's natural and natural resources and have a better cost-effectiveness that was never thought of before.
#
# We need Artificial Intelligence on the battlefield to do
#
# Output 3:
# Artificial Intelligence will become a huge force. You'll be able to create AI that can deal with almost anything, with all sorts of capabilities in AI software, as well as real world situations. It's the kind of world where technology is getting smarter

# %%
# Step 8: Create a custom dataset file

dataset_text = """
Success comes from hard work and dedication.
Never stop learning new things in life.
Believe in yourself and your abilities.
Consistency and patience lead to success.
Dream big and work hard every day.
Great achievements start with small steps.
Hard work always pays off in the end.
Stay positive and keep moving forward.
Failure is just another step toward success.
Confidence and discipline build strong leaders.
"""

with open("dataset.txt", "w") as file:
    file.write(dataset_text)

print("Dataset file created successfully!")
# Out:
# Dataset file created successfully!

# %%
# Step 9: Load and read the dataset

# Open the dataset file we created
with open("dataset.txt", "r") as file:
    data = file.read()

# Print the dataset content
print("Dataset content:\n")
print(data)
# Out:
# Dataset content:
#
#
# Success comes from hard work and dedication.
# Never stop learning new things in life.
# Believe in yourself and your abilities.
# Consistency and patience lead to success.
# Dream big and work hard every day.
# Great achievements start with small steps.
# Hard work always pays off in the end.
# Stay positive and keep moving forward.
# Failure is just another step toward success.
# Confidence and discipline build strong leaders.

# %%
# Step 10: Convert dataset text into tokens

# Tokenize the dataset text so the model can understand it
dataset_tokens = tokenizer.encode(data, return_tensors="pt")

# Print the tokens
print(dataset_tokens)
# Out:
# tensor([[  198, 33244,  2058,   422,  1327,   670,   290, 22445,    13,   198,
#          12295,  2245,  4673,   649,  1243,   287,  1204,    13,   198, 12193,
#          12311,   287,  3511,   290,   534,  7883,    13,   198,  9444,   396,
#           1387,   290, 16336,  1085,   284,  1943,    13,   198, 30571,  1263,
#            290,   670,  1327,   790,  1110,    13,   198, 13681, 16970,   923,
#            351,  1402,  4831,    13,   198, 17309,   670,  1464, 13831,   572,
#            287,   262,   886,    13,   198, 25681,  3967,   290,  1394,  3867,
#           2651,    13,   198, 50015,   318,   655,  1194,  2239,  3812,  1943,
#             13,   198, 18546,  1704,   290, 12883,  1382,  1913,  2766,    13,
#            198]])

# %%
# Step 11: Fine-tuning GPT-2 with our dataset

# Set the model in training mode
model.train()

# Define optimizer (used to update the model weights during training)
optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5)

# We will train for a few steps since our dataset is small
for epoch in range(3):  # training for 3 rounds
    outputs = model(dataset_tokens, labels=dataset_tokens)

    loss = outputs.loss
    loss.backward()

    optimizer.step()
    optimizer.zero_grad()

    print(f"Epoch {epoch+1} Loss:", loss.item())
# Out:
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# Epoch 1 Loss: 3.071748971939087
# Epoch 2 Loss: 2.610110282897949
# Epoch 3 Loss: 2.0274124145507812

# %%
# Step 12: Generate text from the fine-tuned model

# Give a prompt related to our dataset
prompt = "Success in life"

# Convert the prompt into tokens
inputs = tokenizer.encode(prompt, return_tensors="pt")

# Generate text using the fine-tuned model
outputs = model.generate(
    inputs,
    max_length=50,
    num_return_sequences=3,
    do_sample=True
)

# Convert tokens back to readable text
for i, output in enumerate(outputs):
    text = tokenizer.decode(output, skip_special_tokens=True)
    print(f"Generated Text {i+1}:")
    print(text)
    print()
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Text 1:
# Success in life (and the one on which you succeed) and you'll be here first time.
#
# It's so empowering to take an incredible risk every day and help others.
#
# If you know what motivates you to come in every
#
# Generated Text 2:
# Success in life...I've been on a number of teams I'm incredibly proud to be successful. But I'm happy to learn this early and then go all the way and continue my good work.
#
# Gabe:
#
# I've been
#
# Generated Text 3:
# Success in life and health
#
# For the next time you're feeling overwhelmed, stop using a computer to cope and make decisions. Try and do something other than thinking. Your goal is clear, you're not crazy. Don't go crazy. Try
